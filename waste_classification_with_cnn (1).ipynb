# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/"
# Out:
# '10th marksheet meena (1).pdf'
# '12th marksheet meena.pdf'
#  20240911183651_00002.jpg
# 'Aadhar card meena.pdf'
# 'Annual Calendar.gsheet'
# 'assignment maths.pdf'
#  Classroom
# 'Colab Notebooks'
# 'community certificate meena.pdf'
# 'doc rec.pdf'
# 'doc REC,.pdf'
# 'Getting started.pdf'
# 'gmn-qgna-tyb – 17 Feb 2024.pdf'
# 'II YEAR CSE (2024-2028 BATCH) Q os.gdoc'
#  iLovePDF
#  IMG_20200518_171355.jpg
#  IMG_20200518_225231.jpg
# 'IMG-20240519-WA0010 (1).jpg'
#  IMG-20240519-WA0010.jpg
#  inbound2598372048078217556.jpg
#  inbound2798982047780445597.mp4
#  inbound2937090103724532367.jpg
#  inbound5252808681013737804.jpg
#  in.gov.cbse-HSCER-206721112024.pdf
# 'Meena - activity 1 12.05.2020.pdf'
# 'Meena - activity 2 12.05.2020.pdf'
# 'meena documents.pdf'
# 'meena report (1).docx'
# 'meena report.docx'
# 'Meena T documents.pdf'
# 'njp-nnvr-dur – 15 Dec 2023.pdf'
#  nptel.pdf
# 'Screen Recording 2025-09-09 001750.mp4'
# 'Transfer certificate meena.pdf'
# 'Triangles activity .pdf'
# ...

# %%
# !ls "/content/drive/MyDrive/Waste_Classification_Project"
# Out:
# waste-classification-with-cnn.ipynb

# %%
# !ls "/content/drive/MyDrive/Waste_Classification_Project"
# Out:
# waste-classification-with-cnn.ipynb

# %%
train_dir = "/content/drive/MyDrive/Waste_Classification_Project/dataset/train"
test_dir = "/content/drive/MyDrive/Waste_Classification_Project/dataset/test"

# %%
train_dir = "/content/drive/MyDrive/Waste_Classification_Project/DATASET/TRAIN"
test_dir = "/content/drive/MyDrive/Waste_Classification_Project/DATASET/TEST"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_dir = "/content/drive/MyDrive/Waste_Classification_Project/train"
test_dir = "/content/drive/MyDrive/Waste_Classification_Project/test"

# %%
train_dir = "/content/drive/MyDrive/Waste_Classification_Project/DATASET/TRAIN"
test_dir = "/content/drive/MyDrive/Waste_Classification_Project/DATASET/TEST"

# %%
# !ls "$train_dir"
# Out:
# O  R

# %%
# Import libraries
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define dataset paths
train_path = "/content/drive/MyDrive/Waste_Classification_Project/DATASET/TRAIN"
test_path = "/content/drive/MyDrive/Waste_Classification_Project/DATASET/TEST"

# Image parameters
img_height, img_width = 224, 224  # you can use 128x128 too for faster training
batch_size = 32

# Data augmentation for training (helps prevent overfitting)
train_datagen = ImageDataGenerator(
    rescale=1./255,          # normalize pixel values (0–1)
    rotation_range=20,       # random rotation
    width_shift_range=0.2,   # horizontal shift
    height_shift_range=0.2,  # vertical shift
    shear_range=0.2,         # shear transformation
    zoom_range=0.2,          # random zoom
    horizontal_flip=True,    # flip images
    fill_mode='nearest'      # fill missing pixels
)

# Only normalization for test set
test_datagen = ImageDataGenerator(rescale=1./255)

# Create generators
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'  # since we have two classes (O, R)
)

test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)

# Check if classes are loaded properly
print(train_generator.class_indices)
# Out:
# Found 22577 images belonging to 2 classes.
# Found 2528 images belonging to 2 classes.
# {'O': 0, 'R': 1}
